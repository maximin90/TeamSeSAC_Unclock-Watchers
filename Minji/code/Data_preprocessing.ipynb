# %% [markdown]
# ### rate: 미국 국채
# ### df: FOMC, Interview, Speech merge data
# ### news_df: NEWS
# ### is_df: interview + speech
# ### fomc_df: FOMC 회의록
# ### data_df: 금리가 있는 날짜에 맞춰, df 정리한 데이터 -> 최종 데이터

# %% [markdown]
# ##### 뉴스 데이터 합치기

# %%
import pandas as pd
import os

# 엑셀 파일 병합하기
filepath = '/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/'

# 파일 경로
file_list = os.listdir(filepath)
# 경로에 있는 모든 csv 파일 리스트 불러오기
file_list_csv = [file for file in file_list if file.endswith('.csv')]

# 저장할 dataframe
merged_df = pd.DataFrame()

for file in file_list_csv:
    # 파일의 경로
    file_path = os.path.join(filepath, file)

    try:
        # read_csv 기능으로 파일 읽음
        df = pd.read_csv(file_path, dtype='object')

        # 파일이 비어있는지 확인
        if not df.empty:
            # 병합된 데이터프레임에 추가
            merged_df = merged_df.append(df)
        else:
            print(f"Warning: File {file} is empty. Skipping...")
            # 비어있는 파일 삭제
            os.remove(file_path)
    except pd.errors.EmptyDataError:
        print(f"Error: File {file} is empty. Skipping...")
        # 비어있는 파일 삭제
        os.remove(file_path)

# 병합 엑셀 파일 저장
output_filepath = "/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/merged_news_2019~2023.csv"
merged_df.to_csv(output_filepath, index=False, encoding='utf-8-sig', mode='w')

# 병합된 데이터프레임 출력
print(merged_df.head())

# 병합된 데이터프레임의 크기 출력
print("Merged DataFrame Shape:", merged_df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\91pp9\Desktop\종로 새싹_핀테크 데이터 분석가 과정_1기\teamproject\Unclock-Watchers git\Minji\code\Data_preprocessing.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/91pp9/Desktop/%EC%A2%85%EB%A1%9C%20%EC%83%88%EC%8B%B9_%ED%95%80%ED%85%8C%ED%81%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80%20%EA%B3%BC%EC%A0%95_1%EA%B8%B0/teamproject/Unclock-Watchers%20git/Minji/code/Data_preprocessing.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> filepath = '/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/'
#       <a href='vscode-notebook-cell:/c%3A/Users/91pp9/Desktop/%EC%A2%85%EB%A1%9C%20%EC%83%88%EC%8B%B9_%ED%95%80%ED%85%8C%ED%81%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80%20%EA%B3%BC%EC%A0%95_1%EA%B8%B0/teamproject/Unclock-Watchers%20git/Minji/code/Data_preprocessing.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> # 파일 경로
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91pp9/Desktop/%EC%A2%85%EB%A1%9C%20%EC%83%88%EC%8B%B9_%ED%95%80%ED%85%8C%ED%81%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80%20%EA%B3%BC%EC%A0%95_1%EA%B8%B0/teamproject/Unclock-Watchers%20git/Minji/code/Data_preprocessing.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> file_list = os.listdir(filepath)
#       <a href='vscode-notebook-cell:/c%3A/Users/91pp9/Desktop/%EC%A2%85%EB%A1%9C%20%EC%83%88%EC%8B%B9_%ED%95%80%ED%85%8C%ED%81%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80%20%EA%B3%BC%EC%A0%95_1%EA%B8%B0/teamproject/Unclock-Watchers%20git/Minji/code/Data_preprocessing.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> # 경로에 있는 모든 csv 파일 리스트 불러오기
#      <a href='vscode-notebook-cell:/c%3A/Users/91pp9/Desktop/%EC%A2%85%EB%A1%9C%20%EC%83%88%EC%8B%B9_%ED%95%80%ED%85%8C%ED%81%AC%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80%20%EA%B3%BC%EC%A0%95_1%EA%B8%B0/teamproject/Unclock-Watchers%20git/Minji/code/Data_preprocessing.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> file_list_csv = [file for file in file_list if file.endswith('.csv')]
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/'

# %%
import pandas as pd

merged_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/merged_news_2019~2023.csv")

# %%
# 'title' 컬럼 삭제
merged_df = merged_df.drop(columns=['Unnamed: 0','url','title', 'media'])

# %%
merged_df.rename(columns={'content':'Text'}, inplace = True)

# %%
# 'date' 열을 datetime 형식으로 변환
merged_df['date'] = pd.to_datetime(merged_df['date'])

# 'date' 열을 원하는 형식으로 변환
merged_df['date'] = merged_df['date'].dt.strftime("%Y-%m-%d")

merged_df
# Out:
#               date                                               Text
# 0       2019-08-26  Leading stock exchange BSE on Monday launched ...
# 1       2019-08-26  Leading stock exchange BSE on Monday launched ...
# 2       2019-11-22  New Delhi: Leading stock exchange NSE on Frida...
# 3       2019-03-29  The government has left unchanged the interest...
# 4       2019-06-28  Interest rates on small savings schemes such a...
# ...            ...                                                ...
# 395826  2023-09-21  Our portfolio is strategically focused on sect...
# 395827  2023-03-01  In this episode of "Intelligence Matters," hos...
# 395828  2023-03-01  In this episode of "Intelligence Matters," hos...
# 395829  2023-06-01  With help from Eli Okun and Garrett Ross Kevin...
# 395830  2023-09-03  On this "Face the Nation" broadcast, moderated...
#
# [395831 rows x 2 columns]

# %% [markdown]
# ##### FOMC, Interview, Speech

# %%
import pandas as pd

# 주어진 텍스트 파일 경로
file_path = '/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/merge/merged_2018~2023.txt'

# 각 항목을 담을 리스트
data_list = []

# 텍스트 파일을 읽어서 각 항목의 시작 지점을 찾아 리스트에 추가
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()
    for line in lines:
        # 예시로 각 행이 개별 문장 또는 단락으로 구분되어 있다고 가정하고 '\n'로 나누기
        parts = line.strip().split('\n')

        # 리스트에 추가
        data_list.extend(parts)

# 데이터프레임으로 변환
df = pd.DataFrame(data_list, columns=['Text'])
df
# Out:
#                                                   Text
# 0    ﻿"STEVE LIESMAN. Mr. Chairman right, the micro...
# 1    "JIM TANKERSLEY. Hi, Mr. Chairman. Jim Tankers...
# 2    "NICK TIMIRAOS. Thank you. Nick Timiraos, the ...
# 3    "SAM FLEMING. Thanks very much. Sam Fleming fr...
# 4    "HOWARD SCHNEIDER. Howard Schneider with Reute...
# ..                                                 ...
# 128  "Minutes of the Federal Open Market Committee ...
# 129  "Minutes of the Federal Open Market Committee ...
# 130  "Minutes of the Federal Open Market Committee ...
# 131  "Minutes of the Federal Open Market Committee ...
# 132  "Minutes of the Federal Open Market Committee ...
#
# [133 rows x 1 columns]

# %% [markdown]
# ##### news, interview+speech, fomc concat

# %%
merged_df = merged_df.sort_values(by='date')
merged_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/sort_merged_news_2019~2023.csv')

# %%
# news
news_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/sort_merged_news_2019~2023.csv")

# %%
import pandas as pd

# 'Text' 열의 부동 소수점 값을 처리하기 위해 'Text' 열을 문자열로 변환합니다
news_df['Text'] = news_df['Text'].astype(str)

# 'date'로 그룹화하고 텍스트를 결합
news_df = news_df.groupby('date')['Text'].apply(lambda x: ' '.join(x)).reset_index()

news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1784 non-null   object
#  1   Text    1784 non-null   object
# dtypes: object(2)
# memory usage: 28.0+ KB

# %%
news_df['Text'][0]

# %%
# interview + speech
is_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/연설+인터뷰.xlsx")
is_df.rename(columns={'Unnamed: 0':'date', 'Unnamed: 1':'Text'}, inplace = True)
is_df.sort_values(by = 'date', inplace = True)
is_df = is_df.groupby('date')['Text'].apply(lambda x: ' '.join(x)).reset_index()

# 2018년 데이터 제외
is_df = is_df[is_df['date'].str.startswith('2018') == False]
is_df.sort_values(by='date', inplace=True)

is_df.info()

# %%
# fomc
fomc_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/fomc회의록 merged.xlsx")
# 'Text' 열에서 '\n'을 공백으로 대체
fomc_df['Text'] = fomc_df['Text'].str.replace('\n', ' ')
fomc_df['date'] = fomc_df['date'].astype(str)

# 2018년 데이터 제외
fomc_df = fomc_df[fomc_df['date'].str.startswith('2018') == False]
fomc_df.sort_values(by='date', inplace=True)

fomc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 38 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    38 non-null     object
#  1   Text    38 non-null     object
# dtypes: object(2)
# memory usage: 912.0+ bytes

# %%
# news_df + is_df + fomc_df
import pandas as pd

df = pd.concat([news_df, is_df, fomc_df], axis=0, join='outer')

# 'date' 열을 datetime 형식으로 변환
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# 'date' 열의 값을 문자열 형식으로 변환
df['date'] = df['date'].dt.strftime("%Y-%m-%d")
df.sort_values(by = 'date', inplace = True)
df
# Out:
#             date                                               Text
# 0     2019-01-01  The fear of automation and artificial intellig...
# 1     2019-01-02  The manufacturing sector hit a nine-month low ...
# 2     2019-01-03  Futures put the Nasdaq Composite, which is hea...
# 3     2019-01-04  KHARTOUM/CAIRO (Reuters) - Short of time to sa...
# 4     2019-01-05  Federal Reserve Chairman Jerome Powell on Frid...
# ...          ...                                                ...
# 1779  2023-11-16  NEW YORK -- Stocks drifted to a mixed finish T...
# 1780  2023-11-17  Krishna Sanghavi, CIO-Equities, Mahindra Manul...
# 1781  2023-11-18  Comment on this story Comment Add to your save...
# 1782  2023-11-19  Longer-tenure EMIs (equated monthly instalment...
# 1783  2023-11-20  Far-right libertarian Javier Milei has declare...
#
# [1861 rows x 2 columns]

# %%
# 'date'로 그룹화하고 텍스트를 결합
df = df.groupby('date')['Text'].apply(lambda x: ' '.join(x)).reset_index()

df.to_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/all_merged_data.csv')

# %% [markdown]
# ##### 금리

# %%
rate = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/미국 1개월 채권수익률 과거 데이터 (1).csv')
rate.rename(columns={'날짜':'date', '종가':'closing price', '변동 %':'fluctuation'}, inplace = True)
rate = rate.drop(columns=['시가', '고가', '저가'])

# %%
rate = rate[rate['date'].str.startswith('2018') == False]
rate.sort_values(by = 'date', inplace = True)

rate
# Out:
# <ipython-input-80-3daf6e2fb8c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rate.sort_values(by = 'date', inplace = True)
#               date  closing price fluctuation
# 1251  2019- 01- 01          2.435       0.00%
# 1250  2019- 01- 02          2.394      -1.69%
# 1249  2019- 01- 03          2.351      -1.80%
# 1248  2019- 01- 04          2.412       2.59%
# 1247  2019- 01- 07          2.410      -0.08%
# ...            ...            ...         ...
# 4     2023- 10- 25          5.399      -0.06%
# 3     2023- 10- 26          5.395      -0.07%
# 2     2023- 10- 27          5.408       0.24%
# 1     2023- 10- 30          5.400      -0.15%
# 0     2023- 10- 31          5.394      -0.11%
#
# [1252 rows x 3 columns]

# %% [markdown]
# ##### 금리가 없는 날짜 삭제

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1784 non-null   datetime64[ns]
#  1   Text    1784 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 28.0+ KB

# %%
rate['date'] = pd.to_datetime(rate['date'])
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1252 entries, 1251 to 0
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1252 non-null   datetime64[ns]
#  1   closing price  1252 non-null   float64
#  2   fluctuation    1252 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 39.1+ KB

# %%
data_df = pd.merge(df, rate, how='outer', on='date')
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1784
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1785 non-null   datetime64[ns]
#  1   Text           1784 non-null   object
#  2   closing price  1252 non-null   float64
#  3   fluctuation    1252 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 69.7+ KB

# %%
data_df = data_df.dropna()
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1251 entries, 0 to 1763
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1251 non-null   datetime64[ns]
#  1   Text           1251 non-null   object
#  2   closing price  1251 non-null   float64
#  3   fluctuation    1251 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 48.9+ KB

# %%
data_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/complete_data.csv')

# %% [markdown]
# ##### 전처리: 금리 + fomc, interview, speech (2019.01.01 ~ 2023.10.31)

# %%
import pandas as pd

data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/complete_data.csv')

# %%
data_df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  The fear of automation and artificial intellig...
# 1     2019-01-02  The manufacturing sector hit a nine-month low ...
# 2     2019-01-03  Futures put the Nasdaq Composite, which is hea...
# 3     2019-01-04  KHARTOUM/CAIRO (Reuters) - Short of time to sa...
# 4     2019-01-07  LONDON (Reuters) - A set of strong employment ...
# ...          ...                                                ...
# 1246  2023-10-25  New home sales in the United States surged hig...
# 1247  2023-10-26  US stocks fell on Thursday under the pressure ...
# 1248  2023-10-27  The benchmark S&amp;P 500 index closed in corr...
# 1249  2023-10-30  Petronas, Greenko Founders, GIC Set to Put $2b...
# 1250  2023-10-31  Young Americans including Gen Z have their sig...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %% [markdown]
# ###### 정규 표현식 적용_숫자, 특수문자, 2개 이하 삭제

# %%
# preprocessiong: 정규화
import re

data_df['Text'] = data_df['Text'].str.lower()
data_df['Text'] = data_df.apply(lambda row: re.sub(r'\b\w{1,2}\b|[^a-z\s]', '', row['Text']), axis=1)
data_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Unclock-watchers/news/preprocessing_1.csv')

# %%
data_df.head(1)

# %% [markdown]
# ######  . . .

# %%
from nltk.tokenize import word_tokenize

# word_tokenize 해서 Text에 덮어쓰기
data_df['Text'] = data_df['Text'].apply(word_tokenize)

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# 불용어 제거해서 덮어쓰기
data_df['Text'] = data_df['Text'].apply(lambda tokens: [word for word in tokens if word.lower() not in stop_words])

# 결과 확인
data_df.head(3)

# %% [markdown]
# ###### 행 별 불용어 처리

# %%
# 'Text' 열에 대해 불용어 제거 수행
data_df['Text'] = data_df['Text'].apply(lambda row: ' '.join([word for word in word_tokenize(row) if word.lower() not in stop_words]))
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  fear automation artificial intelligence spurre...
# 1     2019-01-02  manufacturing sector hit ninemonth low decembe...
# 2     2019-01-03  futures put nasdaq composite heavily weighted ...
# 3     2019-01-04  khartoumcairo reuters short time save sinking ...
# 4     2019-01-07  london reuters set strong employment data unit...
# ...          ...                                                ...
# 1246  2023-10-25  new home sales united states surged higher sep...
# 1247  2023-10-26  stocks fell thursday pressure disappointing th...
# 1248  2023-10-27  benchmark amp index closed correction territor...
# 1249  2023-10-30  petronas greenko founders gic set put greenpet...
# 1250  2023-10-31  young americans including gen sights set retir...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
data_df.head(1)
# Out:
#          date                                               Text  \
# 0  2019-01-01  the fear  automation and artificial intelligen...
#
#    closing price fluctuation
# 0          2.435       0.00%

# %% [markdown]
# ###### 행별 불용어 및 품사

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords') # 불용어처리
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91pp9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91pp9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\91pp9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91pp9\AppData\Roaming\nltk_data...
# True

# %%
import pandas as pd

data_df = pd.read_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_1.csv", index_col = 0)

# %%
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  the fear  automation and artificial intelligen...
# 1     2019-01-02  the manufacturing sector hit  ninemonth low  d...
# 2     2019-01-03  futures put the nasdaq composite which  heavil...
# 3     2019-01-04  khartoumcairo reuters  short  time  save his s...
# 4     2019-01-07  london reuters   set  strong employment data  ...
# ...          ...                                                ...
# 1246  2023-10-25  new home sales  the united states surged highe...
# 1247  2023-10-26   stocks fell  thursday under the pressure  dis...
# 1248  2023-10-27  the benchmark amp  index closed  correction te...
# 1249  2023-10-30  petronas greenko founders gic set  put    gree...
# 1250  2023-10-31  young americans including gen  have their sigh...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = stopwords.words('english')

data_df['Text'] = data_df['Text'].apply(lambda row: [word for word in word_tokenize(row) if word.lower() not in stop_words])

# %%
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  [fear, automation, artificial, intelligence, s...
# 1     2019-01-02  [manufacturing, sector, hit, ninemonth, low, d...
# 2     2019-01-03  [futures, put, nasdaq, composite, heavily, wei...
# 3     2019-01-04  [khartoumcairo, reuters, short, time, save, si...
# 4     2019-01-07  [london, reuters, set, strong, employment, dat...
# ...          ...                                                ...
# 1246  2023-10-25  [new, home, sales, united, states, surged, hig...
# 1247  2023-10-26  [stocks, fell, thursday, pressure, disappointi...
# 1248  2023-10-27  [benchmark, amp, index, closed, correction, te...
# 1249  2023-10-30  [petronas, greenko, founders, gic, set, put, g...
# 1250  2023-10-31  [young, americans, including, gen, sights, set...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
# preprocessing_2: 불용어 
data_df.to_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_2.csv")

# %%
import pandas as pd

data_df = pd.read_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_2.csv", index_col = 0)
# data_df.drop('Unnamed: 0', axis = 1, inplace = True)
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  ['fear', 'automation', 'artificial', 'intellig...
# 1     2019-01-02  ['manufacturing', 'sector', 'hit', 'ninemonth'...
# 2     2019-01-03  ['futures', 'put', 'nasdaq', 'composite', 'hea...
# 3     2019-01-04  ['khartoumcairo', 'reuters', 'short', 'time', ...
# 4     2019-01-07  ['london', 'reuters', 'set', 'strong', 'employ...
# ...          ...                                                ...
# 1246  2023-10-25  ['new', 'home', 'sales', 'united', 'states', '...
# 1247  2023-10-26  ['stocks', 'fell', 'thursday', 'pressure', 'di...
# 1248  2023-10-27  ['benchmark', 'amp', 'index', 'closed', 'corre...
# 1249  2023-10-30  ['petronas', 'greenko', 'founders', 'gic', 'se...
# 1250  2023-10-31  ['young', 'americans', 'including', 'gen', 'si...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
import re
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# 데이터프레임의 'Text' 열에 있는 각 행에 대해 처리
for idx, row in data_df.iterrows():
    # 정규 표현식을 사용하여 특수문자 제거 
    cleaned_text = re.sub(r"[^a-zA-Z0-9\s]", "", row['Text'])
    # 토큰화 및 품사 태깅
    tokens = word_tokenize(cleaned_text)
    pos_tags = pos_tag(tokens)
    
    # 품사 태깅 결과를 데이터프레임에 저장 (예시로 'POS_Tagging' 열에 저장)
    data_df.at[idx, 'Text'] = pos_tags

# 결과 확인
data_df['Text'][0]
# Out:
# [('fear', 'NN'),
#  ('automation', 'NN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('spurred', 'VBD'),
#  ('countless', 'JJ'),
#  ('conversations', 'NNS'),
#  ('future', 'JJ'),
#  ('work', 'NN'),
#  ('humans', 'NNS'),
#  ('fare', 'JJ'),
#  ('age', 'NN'),
#  ('robots', 'VBD'),
#  ('many', 'JJ'),
#  ('fear', 'JJ'),
#  ('technological', 'JJ'),
#  ('unemployment', 'NN'),
#  ('others', 'NNS'),
#  ('preemptively', 'RB'),
#  ('denounce', 'JJ'),
#  ('future', 'JJ'),
#  ('income', 'NN'),
#  ('inequality', 'NN'),
#  ('confront', 'VBP'),
#  ('dismal', 'JJ'),
#  ('future', 'JJ'),
#  ('work', 'NN'),
#  ('many', 'JJ'),
#  ('policy', 'NN'),
#  ('world', 'NN'),
#  ('tech', 'NN'),
#  ('world', 'NN'),
#  ('even', 'RB'),
#  ('aspiring', 'VBG'),
#  ('presidential', 'JJ'),
#  ('candidates', 'NNS'),
#  ('like', 'IN'),
#  ('andrew', 'NN'),
#  ('yang', 'NN'),
#  ('tout', 'IN'),
#  ('promise', 'NN'),
#  ('universal', 'JJ'),
#  ('basic', 'JJ'),
#  ('income', 'NN'),
#  ('ubi', 'JJ'),
#  ('overcome', 'JJ'),
#  ('uncertainties', 'NNS'),
#  ('whether', 'IN'),
#  ('policymakers', 'NNS'),
#  ('even', 'RB'),
#  ('consider', 'VBP'),
#  ('ideas', 'NNS'),
#  ('ubi', 'RB'),
#  ('given', 'VBN'),
#  ('recent', 'JJ'),
#  ('studies', 'NNS'),
#  ('suggest', 'VBP'),
#  ('expanded', 'VBN'),
#  ('labor', 'NN'),
#  ('market', 'NN'),
#  ('future', 'NN'),
#  ('relatively', 'RB'),
#  ('strong', 'JJ'),
#  ('current', 'JJ'),
#  ('economic', 'JJ'),
#  ('conditions', 'NNS'),
#  ('still', 'RB'),
#  ('open', 'JJ'),
#  ('question', 'NN'),
#  ('rather', 'RB'),
#  ('focusing', 'VBG'),
#  ('familiar', 'JJ'),
#  ('concerns', 'NNS'),
#  ('ubi', 'JJ'),
#  ('risk', 'NN'),
#  ('dependency', 'NN'),
#  ('price', 'NN'),
#  ('tag', 'NN'),
#  ('implement', 'NN'),
#  ('work', 'NN'),
#  ('often', 'RB'),
#  ('provides', 'VBZ'),
#  ('meaning', 'VBG'),
#  ('one', 'CD'),
#  ('life', 'NN'),
#  ('worthwhile', 'NN'),
#  ('recognize', 'VB'),
#  ('case', 'NN'),
#  ('broad', 'JJ'),
#  ('radical', 'JJ'),
#  ('reform', 'NN'),
#  ('economic', 'JJ'),
#  ('system', 'NN'),
#  ('actually', 'RB'),
#  ('rather', 'RB'),
#  ('weak', 'JJ'),
#  ('although', 'IN'),
#  ('influential', 'JJ'),
#  ('forecast', 'NN'),
#  ('oxford', 'NN'),
#  ('university', 'NN'),
#  ('reported', 'VBD'),
#  ('percent', 'NN'),
#  ('jobs', 'NNS'),
#  ('percent', 'NN'),
#  ('high', 'JJ'),
#  ('risk', 'NN'),
#  ('automated', 'VBD'),
#  ('following', 'VBG'),
#  ('years', 'NNS'),
#  ('recent', 'JJ'),
#  ('study', 'NN'),
#  ('organisation', 'NN'),
#  ('economic', 'JJ'),
#  ('cooperation', 'NN'),
#  ('development', 'NN'),
#  ('oecd', 'NN'),
#  ('puts', 'VBZ'),
#  ('figure', 'JJ'),
#  ('percent', 'NN'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('percent', 'NN'),
#  ('united', 'JJ'),
#  ('kingdom', 'NN'),
#  ('moreover', 'RB'),
#  ('recent', 'JJ'),
#  ('study', 'NN'),
#  ('future', 'NN'),
#  ('jobs', 'NNS'),
#  ('world', 'NN'),
#  ('economic', 'JJ'),
#  ('forum', 'NN'),
#  ('predicts', 'NNS'),
#  ('robots', 'VBP'),
#  ('displace', 'NN'),
#  ('million', 'CD'),
#  ('jobs', 'NNS'),
#  ('globally', 'RB'),
#  ('create', 'VBP'),
#  ('million', 'CD'),
#  ('new', 'JJ'),
#  ('ones', 'NNS'),
#  ('net', 'JJ'),
#  ('positive', 'JJ'),
#  ('overall', 'JJ'),
#  ('numbers', 'NNS'),
#  ('hardly', 'RB'),
#  ('scary', 'JJ'),
#  ('concerns', 'NNS'),
#  ('remain', 'VBP'),
#  ('growing', 'VBG'),
#  ('number', 'NN'),
#  ('researchers', 'NNS'),
#  ('across', 'IN'),
#  ('political', 'JJ'),
#  ('spectrum', 'NN'),
#  ('taking', 'VBG'),
#  ('interest', 'NN'),
#  ('concept', 'NN'),
#  ('ubi', 'RB'),
#  ('much', 'JJ'),
#  ('automation', 'NN'),
#  ('disruption', 'NN'),
#  ('lies', 'VBZ'),
#  ('heart', 'NN'),
#  ('discussions', 'NNS'),
#  ('future', 'JJ'),
#  ('work', 'NN'),
#  ('comes', 'VBZ'),
#  ('silicon', 'JJ'),
#  ('valley', 'NN'),
#  ('entrepreneurs', 'NNS'),
#  ('valley', 'VBP'),
#  ('often', 'RB'),
#  ('tried', 'VBN'),
#  ('suggest', 'VBP'),
#  ('proactive', 'JJ'),
#  ('solutions', 'NNS'),
#  ('one', 'CD'),
#  ('latest', 'JJS'),
#  ('experiments', 'NNS'),
#  ('ubi', 'JJ'),
#  ('one', 'CD'),
#  ('currently', 'RB'),
#  ('pursued', 'VBN'),
#  ('combinator', 'NN'),
#  ('silicon', 'NN'),
#  ('valley', 'NN'),
#  ('seed', 'NN'),
#  ('funder', 'NN'),
#  ('combinator', 'NN'),
#  ('reported', 'VBD'),
#  ('million', 'CD'),
#  ('ubi', 'JJ'),
#  ('experiment', 'JJ'),
#  ('start', 'NN'),
#  ('experiment', 'NN'),
#  ('consists', 'VBZ'),
#  ('giving', 'VBG'),
#  ('people', 'NNS'),
#  ('per', 'IN'),
#  ('month', 'NN'),
#  ('five', 'CD'),
#  ('years', 'NNS'),
#  ('discussing', 'VBG'),
#  ('motivation', 'NN'),
#  ('experiment', 'NN'),
#  ('assert', 'JJ'),
#  ('extreme', 'JJ'),
#  ('poverty', 'NN'),
#  ('dramatically', 'RB'),
#  ('increased', 'VBD'),
#  ('middle', 'JJ'),
#  ('class', 'NN'),
#  ('shrinking', 'VBG'),
#  ('employment', 'NN'),
#  ('incomes', 'VBZ'),
#  ('become', 'VBN'),
#  ('volatile', 'JJ'),
#  ('unpredictable', 'JJ'),
#  ('fortunately', 'RB'),
#  ('none', 'NN'),
#  ('data', 'NNS'),
#  ('confirm', 'VBP'),
#  ('dreary', 'JJ'),
#  ('assertions', 'NNS'),
#  ('recent', 'JJ'),
#  ('report', 'NN'),
#  ('released', 'VBD'),
#  ('census', 'NN'),
#  ('bureau', 'NN'),
#  ('poverty', 'NN'),
#  ('continued', 'VBD'),
#  ('decline', 'JJ'),
#  ('third', 'JJ'),
#  ('consecutive', 'JJ'),
#  ('year', 'NN'),
#  ('modest', 'JJ'),
#  ('positive', 'JJ'),
#  ('wage', 'NN'),
#  ('growth', 'NN'),
#  ('inequality', 'NN'),
#  ('statistically', 'RB'),
#  ('different', 'JJ'),
#  ('middle', 'JJ'),
#  ('class', 'NN'),
#  ('economist', 'NN'),
#  ('mark', 'NN'),
#  ('perry', 'NN'),
#  ('reports', 'NNS'),
#  ('shrinking', 'VBG'),
#  ('people', 'NNS'),
#  ('better', 'JJR'),
#  ('members', 'NNS'),
#  ('middle', 'JJ'),
#  ('class', 'NN'),
#  ('joining', 'VBG'),
#  ('ranks', 'NNS'),
#  ('upper', 'JJ'),
#  ('class', 'NN'),
#  ('causing', 'VBG'),
#  ('middle', 'JJ'),
#  ('shrink', 'NN'),
#  ('latest', 'JJS'),
#  ('unemployment', 'NN'),
#  ('rate', 'NN'),
#  ('percent', 'NN'),
#  ('million', 'CD'),
#  ('current', 'JJ'),
#  ('job', 'NN'),
#  ('openings', 'NNS'),
#  ('according', 'VBG'),
#  ('bureau', 'NN'),
#  ('labor', 'NN'),
#  ('statistics', 'NNS'),
#  ('need', 'VBP'),
#  ('experiment', 'JJ'),
#  ('dramatic', 'JJ'),
#  ('changes', 'NNS'),
#  ('social', 'JJ'),
#  ('safety', 'NN'),
#  ('net', 'NN'),
#  ('like', 'IN'),
#  ('ubi', 'JJ'),
#  ('seems', 'VBZ'),
#  ('overblown', 'JJ'),
#  ('furthermore', 'RB'),
#  ('recent', 'JJ'),
#  ('bloomberg', 'NN'),
#  ('article', 'NN'),
#  ('based', 'VBN'),
#  ('study', 'NN'),
#  ('conference', 'NN'),
#  ('board', 'NN'),
#  ('even', 'RB'),
#  ('describes', 'VBZ'),
#  ('shortage', 'JJ'),
#  ('workers', 'NNS'),
#  ('many', 'JJ'),
#  ('industries', 'NNS'),
#  ('although', 'IN'),
#  ('typically', 'RB'),
#  ('vocal', 'JJ'),
#  ('supporters', 'NNS'),
#  ('ubi', 'VBP'),
#  ('everyone', 'NN'),
#  ('silicon', 'NN'),
#  ('valley', 'NN'),
#  ('fearful', 'JJ'),
#  ('future', 'JJ'),
#  ('work', 'NN'),
#  ('actually', 'RB'),
#  ('welcome', 'JJ'),
#  ('column', 'NN'),
#  ('wired', 'VBD'),
#  ('magazine', 'NN'),
#  ('palantir', 'NN'),
#  ('founder', 'NN'),
#  ('joe', 'NN'),
#  ('lonsdale', 'NN'),
#  ('outlined', 'VBD'),
#  ('various', 'JJ'),
#  ('industries', 'NNS'),
#  ('new', 'JJ'),
#  ('types', 'NNS'),
#  ('jobs', 'NNS'),
#  ('continue', 'VBP'),
#  ('created', 'VBN'),
#  ('lonsdale', 'NN'),
#  ('puts', 'VBZ'),
#  ('money', 'NN'),
#  ('mouth', 'NN'),
#  ('work', 'NN'),
#  ('palantir', 'NN'),
#  ('harnesses', 'VBZ'),
#  ('power', 'NN'),
#  ('solve', 'NN'),
#  ('complex', 'NN'),
#  ('problems', 'NNS'),
#  ('using', 'VBG'),
#  ('big', 'JJ'),
#  ('data', 'NNS'),
#  ('variety', 'NN'),
#  ('industries', 'NNS'),
#  ('improving', 'VBG'),
#  ('productivity', 'NN'),
#  ('shifting', 'VBG'),
#  ('nature', 'NN'),
#  ('jobs', 'NNS'),
#  ('rather', 'RB'),
#  ('destroying', 'VBG'),
#  ('much', 'JJ'),
#  ('discussion', 'NN'),
#  ('around', 'IN'),
#  ('ubi', 'JJ'),
#  ('future', 'NN'),
#  ('work', 'NN'),
#  ('triggered', 'VBD'),
#  ('concern', 'NN'),
#  ('future', 'JJ'),
#  ('lack', 'NN'),
#  ('upward', 'JJ'),
#  ('economic', 'JJ'),
#  ('mobility', 'NN'),
#  ('increase', 'NN'),
#  ('income', 'NN'),
#  ('inequality', 'NN'),
#  ('however', 'RB'),
#  ('reasons', 'NNS'),
#  ('might', 'MD'),
#  ('less', 'VB'),
#  ('upward', 'JJ'),
#  ('economic', 'JJ'),
#  ('mobility', 'NN'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('wed', 'VBD'),
#  ('like', 'IN'),
#  ('discussed', 'JJ'),
#  ('researchers', 'NNS'),
#  ('raj', 'VBP'),
#  ('chetty', 'JJ'),
#  ('scott', 'NN'),
#  ('winship', 'NN'),
#  ('almost', 'RB'),
#  ('certainly', 'RB'),
#  ('due', 'JJ'),
#  ('factors', 'NNS'),
#  ('require', 'VBP'),
#  ('drastic', 'JJ'),
#  ('change', 'NN'),
#  ('welfare', 'NN'),
#  ('economic', 'JJ'),
#  ('policies', 'NNS'),
#  ('one', 'CD'),
#  ('factor', 'NN'),
#  ('decline', 'NN'),
#  ('male', 'NN'),
#  ('labor', 'NN'),
#  ('force', 'NN'),
#  ('participation', 'NN'),
#  ('complex', 'NN'),
#  ('problem', 'NN'),
#  ('multiple', 'JJ'),
#  ('causes', 'VBZ'),
#  ('among', 'IN'),
#  ('likely', 'JJ'),
#  ('excessive', 'JJ'),
#  ('use', 'NN'),
#  ('disability', 'NN'),
#  ('programs', 'NNS'),
#  ('job', 'NN'),
#  ('polarization', 'NN'),
#  ('middleskill', 'FW'),
#  ('workers', 'NNS'),
#  ('less', 'RBR'),
#  ('demand', 'NN'),
#  ('skills', 'NNS'),
#  ('gap', 'VBP'),
#  ('soft', 'JJ'),
#  ('skills', 'NNS'),
#  ('included', 'VBD'),
#  ('highlighted', 'JJ'),
#  ('people', 'NNS'),
#  ('like', 'IN'),
#  ('mike', 'NN'),
#  ('rowe', 'NN'),
#  ('creates', 'VBZ'),
#  ('frictions', 'NNS'),
#  ('labor', 'NN'),
#  ('market', 'NN'),
#  ('reasons', 'NNS'),
#  ('include', 'VBP'),
#  ('steep', 'JJ'),
#  ('decline', 'NN'),
#  ('business', 'NN'),
#  ('dynamism', 'NN'),
#  ('since', 'IN'),
#  ('fewer', 'JJR'),
#  ('startups', 'NNS'),
#  ('created', 'VBD'),
#  ('due', 'JJ'),
#  ('variety', 'NN'),
#  ('factors', 'NNS'),
#  ('one', 'CD'),
#  ('occupational', 'JJ'),
#  ('licensing', 'NN'),
#  ('laws', 'NNS'),
#  ('restrict', 'VBP'),
#  ('employment', 'NN'),
#  ('opportunities', 'NNS'),
#  ('shown', 'VBN'),
#  ('related', 'JJ'),
#  ('lower', 'JJR'),
#  ('levels', 'NNS'),
#  ('economic', 'JJ'),
#  ('mobility', 'NN'),
#  ('higher', 'JJR'),
#  ('levels', 'NNS'),
#  ('income', 'NN'),
#  ('inequality', 'NN'),
#  ('local', 'JJ'),
#  ('zoning', 'VBG'),
#  ('laws', 'NNS'),
#  ('affect', 'VBP'),
#  ('lowincome', 'JJ'),
#  ('workers', 'NNS'),
#  ('afford', 'VBP'),
#  ('live', 'JJ'),
#  ('high', 'JJ'),
#  ('incarceration', 'NN'),
#  ('rates', 'NNS'),
#  ('affect', 'VBP'),
#  ('opportunities', 'NNS'),
#  ('upward', 'VBP'),
#  ('economic', 'JJ'),
#  ('mobility', 'NN'),
#  ('leave', 'VBP'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('especially', 'RB'),
#  ('males', 'NNS'),
#  ('labor', 'NN'),
#  ('force', 'NN'),
#  ('fixing', 'VBG'),
#  ('issues', 'NNS'),
#  ('often', 'RB'),
#  ('state', 'NN'),
#  ('local', 'JJ'),
#  ('level', 'NN'),
#  ('help', 'NN'),
#  ('produce', 'VB'),
#  ('dynamic', 'JJ'),
#  ('healthy', 'JJ'),
#  ('economy', 'NN'),
#  ('removing', 'VBG'),
#  ('barriers', 'NNS'),
#  ('currently', 'RB'),
#  ('prevent', 'VBP'),
#  ('people', 'NNS'),
#  ('moving', 'VBG'),
#  ('income', 'NN'),
#  ('ladder', 'NN'),
#  ('may', 'MD'),
#  ('seem', 'VB'),
#  ('mundane', 'NN'),
#  ('comparison', 'NN'),
#  ('radical', 'JJ'),
#  ('proposals', 'NNS'),
#  ('tackling', 'VBG'),
#  ('problems', 'NNS'),
#  ('would', 'MD'),
#  ('increase', 'VB'),
#  ('ability', 'NN'),
#  ('face', 'NN'),
#  ('future', 'NN'),
#  ('automation', 'NN'),
#  ('likely', 'RB'),
#  ('boost', 'VB'),
#  ('upward', 'JJ'),
#  ('mobility', 'NN'),
#  ('even', 'RB'),
#  ('reduce', 'VB'),
#  ('inequality', 'NN'),
#  ('along', 'IN'),
#  ('way', 'NN'),
#  ('welcoming', 'VBG'),
#  ('innovation', 'NN'),
#  ('remembering', 'VBG'),
#  ('human', 'JJ'),
#  ('ingenuity', 'NN'),
#  ('ultimate', 'JJ'),
#  ('resource', 'NN'),
#  ('cornerstones', 'NNS'),
#  ('every', 'DT'),
#  ('discussion', 'NN'),
#  ('future', 'NN'),
#  ('work', 'NN'),
#  ('gonzalo', 'JJ'),
#  ('schwarz', 'JJ'),
#  ('president', 'NN'),
#  ('ceo', 'NN'),
#  ('archbridge', 'IN'),
#  ('institute', 'NN'),
#  ('based', 'VBN'),
#  ('nonprofit', 'JJ'),
#  ('organization', 'NN'),
#  ('advocating', 'VBG'),
#  ('behalf', 'JJ'),
#  ('free', 'JJ'),
#  ('markets', 'NNS'),
#  ('limited', 'JJ'),
#  ('government', 'NN'),
#  ('regulations', 'NNS'),
#  ('sankaran', 'VBD'),
#  ('narencalendar', 'RB'),
#  ('likely', 'JJ'),
#  ('interesting', 'JJ'),
#  ('year', 'NN'),
#  ('investors', 'NNS'),
#  ('market', 'NN'),
#  ('braces', 'NNS'),
#  ('nearterm', 'VBP'),
#  ('volatility', 'NN'),
#  ('owing', 'VBG'),
#  ('major', 'JJ'),
#  ('nearterm', 'JJ'),
#  ('event', 'NN'),
#  ('general', 'JJ'),
#  ('elections', 'NNS'),
#  ('date', 'NN'),
#  ('indian', 'JJ'),
#  ('equity', 'NN'),
#  ('market', 'NN'),
#  ('fairly', 'RB'),
#  ('valued', 'VBN'),
#  ('neither', 'CC'),
#  ('cheap', 'JJ'),
#  ('expensive', 'JJ'),
#  ('importantly', 'RB'),
#  ('focus', 'VBP'),
#  ('individual', 'JJ'),
#  ('stock', 'NN'),
#  ('picking', 'VBG'),
#  ('plenty', 'JJ'),
#  ('opportunities', 'NNS'),
#  ('available', 'JJ'),
#  ('attractive', 'JJ'),
#  ('valuations', 'NNS'),
#  ('several', 'JJ'),
#  ('uplifting', 'JJ'),
#  ('factors', 'NNS'),
#  ('keeping', 'VBG'),
#  ('market', 'NN'),
#  ('upbeat', 'NN'),
#  ('begin', 'VB'),
#  ('fall', 'JJ'),
#  ('crude', 'NN'),
#  ('oil', 'NN'),
#  ('prices', 'NNS'),
#  ('sentiment', 'NN'),
#  ('booster', 'NN'),
#  ('greatly', 'RB'),
#  ('reduced', 'JJ'),
#  ('pressure', 'NN'),
#  ('twin', 'VB'),
#  ('deficits', 'NNS'),
#  ('current', 'JJ'),
#  ('account', 'NN'),
#  ('fiscal', 'JJ'),
#  ('consequently', 'RB'),
#  ('rupee', 'VBP'),
#  ('turned', 'VBN'),
#  ('around', 'IN'),
#  ('dollar', 'NN'),
#  ('bond', 'NN'),
#  ('yields', 'NNS'),
#  ('coming', 'VBG'),
#  ('lowering', 'VBG'),
#  ('interest', 'NN'),
#  ('burden', 'NN'),
#  ('economy', 'NN'),
#  ('macro', 'JJ'),
#  ('figures', 'NNS'),
#  ('showing', 'VBG'),
#  ('signs', 'NNS'),
#  ('financial', 'JJ'),
#  ('stability', 'NN'),
#  ('near', 'IN'),
#  ('mediumterm', 'JJ'),
#  ('perspective', 'JJ'),
#  ('equity', 'NN'),
#  ('market', 'NN'),
#  ('likely', 'RB'),
#  ('remain', 'VBP'),
#  ('volatile', 'JJ'),
#  ('historically', 'RB'),
#  ('election', 'NN'),
#  ('years', 'NNS'),
#  ('proved', 'VBD'),
#  ('volatile', 'JJ'),
#  ('financial', 'JJ'),
#  ('markets', 'NNS'),
#  ('general', 'JJ'),
#  ('past', 'IN'),
#  ('across', 'IN'),
#  ('election', 'NN'),
#  ('years', 'NNS'),
#  ('stock', 'NN'),
#  ('market', 'NN'),
#  ('provided', 'VBD'),
#  ('investors', 'NNS'),
#  ('intermittent', 'JJ'),
#  ('opportunities', 'NNS'),
#  ('invest', 'VBP'),
#  ('times', 'RB'),
#  ('best', 'JJ'),
#  ('investment', 'NN'),
#  ('strategy', 'NN'),
#  ('use', 'VBP'),
#  ('systematic', 'JJ'),
#  ('investment', 'NN'),
#  ('route', 'NN'),
#  ('accumulate', 'NN'),
#  ('equities', 'NNS'),
#  ('believe', 'VBP'),
#  ('year', 'NN'),
#  ('systematically', 'RB'),
#  ('accumulate', 'JJ'),
#  ('equities', 'NNS'),
#  ('sip', 'VBP'),
#  ('stps', 'JJ'),
#  ('keeping', 'VBG'),
#  ('emotional', 'JJ'),
#  ('biases', 'NNS'),
#  ('bay', 'VBP'),
#  ('accumulation', 'NN'),
#  ('phase', 'NN'),
#  ('generally', 'RB'),
#  ('comes', 'VBZ'),
#  ('precursor', 'JJ'),
#  ('bull', 'JJ'),
#  ('run', 'NN'),
#  ('thus', 'RB'),
#  ('important', 'JJ'),
#  ('patient', 'NN'),
#  ('remain', 'NN'),
#  ('invested', 'JJ'),
#  ('phase', 'NN'),
#  ('make', 'VBP'),
#  ('outsized', 'JJ'),
#  ('gains', 'NNS'),
#  ('likely', 'JJ'),
#  ('market', 'NN'),
#  ('uptick', 'JJ'),
#  ('ensues', 'NNS'),
#  ('phase', 'VBP'),
#  ('recent', 'JJ'),
#  ('example', 'NN'),
#  ('phase', 'NN'),
#  ('period', 'NN'),
#  ('stock', 'NN'),
#  ('markets', 'NNS'),
#  ('largely', 'RB'),
#  ('rangebound', 'VBP'),
#  ('investors', 'NNS'),
#  ('stayed', 'VBD'),
#  ('invested', 'JJ'),
#  ('rewards', 'NNS'),
#  ('came', 'VBD'),
#  ('years', 'NNS'),
#  ('stock', 'NN'),
#  ('market', 'NN'),
#  ('entered', 'VBD'),
#  ('bull', 'JJ'),
#  ('phase', 'NN'),
#  ('amidst', 'NN'),
#  ('investors', 'NNS'),
#  ('need', 'VBP'),
#  ('watchful', 'JJ'),
#  ('factors', 'NNS'),
#  ('begin', 'VBP'),
#  ('fed', 'VBN'),
#  ('stance', 'JJ'),
#  ('interest', 'NN'),
#  ('rates', 'NNS'),
#  ('factor', 'VBP'),
#  ('watch', 'JJ'),
#  ('meaningful', 'JJ'),
#  ('rally', 'NN'),
#  ('indian', 'JJ'),
#  ('equities', 'NNS'),
#  ('likely', 'JJ'),
#  ('fed', 'VBP'),
#  ('done', 'VBN'),
#  ('tightening', 'NN'),
#  ('along', 'IN'),
#  ('accumulation', 'NN'),
#  ('phase', 'NN'),
#  ('likely', 'RB'),
#  ('come', 'JJ'),
#  ('end', 'VBP'),
#  ('keeping', 'VBG'),
#  ('view', 'NN'),
#  ('stance', 'NN'),
#  ('believe', 'VBP'),
#  ('current', 'JJ'),
#  ('investing', 'VBG'),
#  ('climate', 'NN'),
#  ('conducive', 'JJ'),
#  ('investors', 'NNS'),
#  ('initiate', 'VBP'),
#  ('continue', 'VB'),
#  ('systematic', 'JJ'),
#  ('investment', 'NN'),
#  ('equity', 'NN'),
#  ('assets', 'NNS'),
#  ('smallcaps', 'VBP'),
#  ('midcaps', 'NNS'),
#  ('value', 'NN'),
#  ('funds', 'NNS'),
#  ('looking', 'VBG'),
#  ('making', 'VBG'),
#  ('lumpsum', 'JJ'),
#  ('investments', 'NNS'),
#  ('balanced', 'VBN'),
#  ('advantage', 'JJ'),
#  ('funds', 'NNS'),
#  ('equity', 'NN'),
#  ('savings', 'NNS'),
#  ('funds', 'NNS'),
#  ('preferred', 'JJ'),
#  ('vehicles', 'NNS'),
#  ('fund', 'NN'),
#  ('categories', 'NNS'),
#  ('exposure', 'VBP'),
#  ('equity', 'NN'),
#  ('debt', 'NN'),
#  ('thus', 'RB'),
#  ('provide', 'VB'),
#  ('margin', 'NN'),
#  ('safety', 'NN'),
#  ('things', 'NNS'),
#  ('get', 'VBP'),
#  ('choppy', 'JJ'),
#  ('terms', 'NNS'),
#  ('themes', 'NNS'),
#  ('positive', 'JJ'),
#  ('special', 'JJ'),
#  ('situations', 'NNS'),
#  ('benefitting', 'VBG'),
#  ('volatility', 'NN'),
#  ('debt', 'NN'),
#  ('dynamic', 'JJ'),
#  ('duration', 'NN'),
#  ('schemes', 'NNS'),
#  ('benefit', 'VBP'),
#  ('volatility', 'NN'),
#  ('low', 'JJ'),
#  ('duration', 'NN'),
#  ('funds', 'NNS'),
#  ('tend', 'VBP'),
#  ('mitigate', 'JJ'),
#  ('interest', 'NN'),
#  ('rate', 'NN'),
#  ('volatility', 'NN'),
#  ('investing', 'VBG'),
#  ('instruments', 'NNS'),
#  ('maturity', 'NN'),
#  ('range', 'VBP'),
#  ('years', 'NNS'),
#  ('along', 'IN'),
#  ('accrual', 'JJ'),
#  ('schemes', 'NNS'),
#  ('capture', 'VBP'),
#  ('current', 'JJ'),
#  ('elevated', 'JJ'),
#  ('yields', 'NNS'),
#  ('categories', 'NNS'),
#  ('positive', 'JJ'),
#  ('look', 'NN'),
#  ('may', 'MD'),
#  ('hold', 'VB'),
#  ('yousankaran', 'RP'),
#  ('naren', 'JJ'),
#  ('cio', 'NN'),
#  ('icici', 'NN'),
#  ('prudential', 'JJ'),
#  ('mutual', 'JJ'),
#  ('fund', 'NN'),
#  ('views', 'NNS'),
#  ('latest', 'JJS'),
#  ('rail', 'NN'),
#  ('fare', 'NN'),
#  ('rise', 'NN'),
#  ('takes', 'VBZ'),
#  ('effect', 'NN'),
#  ('first', 'JJ'),
#  ('working', 'VBG'),
#  ('day', 'NN'),
#  ('pushed', 'VBD'),
#  ('cost', 'NN'),
#  ('intercity', 'NN'),
#  ('travel', 'NN'),
#  ('commuters', 'NNS'),
#  ('mile', 'VBP'),
#  ('anytime', 'JJ'),
#  ('standardclass', 'NN'),
#  ('fare', 'NN'),
#  ('mile', 'JJ'),
#  ('journey', 'NN'),
#  ('swindon', 'NN'),
#  ('didcot', 'JJ'),
#  ('parkway', 'NN'),
#  ('rises', 'VBZ'),
#  ('january', 'JJ'),
#  ('price', 'NN'),
#  ('mile', 'NN'),
#  ('gwr', 'NN'),
#  ('fare', 'NN'),
#  ('option', 'NN'),
#  ('commuters', 'NNS'),
#  ('want', 'VBP'),
#  ('walk', 'NN'),
#  ('ticket', 'NN'),
#  ('minute', 'NN'),
#  ('journey', 'NN'),
#  ('join', 'NN'),
#  ('independent', 'JJ'),
#  ('minds', 'NNS'),
#  ('exclusive', 'JJ'),
#  ('articles', 'NNS'),
#  ('events', 'NNS'),
#  ('advertisingfree', 'JJ'),
#  ('read', 'JJ'),
#  ('month', 'NN'),
#  ('start', 'VBD'),
#  ('free', 'JJ'),
#  ('trial', 'NN'),
#  ('get', 'NN'),
#  ('best', 'RBS'),
#  ('independent', 'JJ'),
#  ('independent', 'JJ'),
#  ('minds', 'NNS'),
#  ('subscription', 'JJ'),
#  ('month', 'NN'),
#  ('start', 'RB'),
#  ('free', 'JJ'),
#  ('trial', 'NN'),
#  ('heathrow', 'NN'),
#  ('express', 'NN'),
#  ('remains', 'VBZ'),
#  ('britains', 'VBZ'),
#  ('priciest', 'JJS'),
#  ('train', 'NN'),
#  ('mile', 'NN'),
#  ('significant', 'JJ'),
#  ('intercity', 'NN'),
#  ('journey', 'NN'),
#  ('rise', 'NN'),
#  ('pound', 'NN'),
#  ('per', 'IN'),
#  ('mile', 'NN'),
#  ('unprecedented', 'JJ'),
#  ('mile', 'NN'),
#  ('trip', 'NN'),
#  ('watford', 'NN'),
#  ('junction', 'NN'),
#  ('stockport', 'NN'),
#  ('virgin', 'NN'),
#  ('trains', 'NNS'),
#  ('also', 'RB'),
#  ('exceeds', 'VBP'),
#  ('mile', 'JJ'),
#  ('fare', 'NN'),
#  ('rises', 'VBZ'),
#  ('representing', 'VBG'),
#  ('rate', 'NN'),
#  ('rational', 'JJ'),
#  ('traveller', 'NN'),
#  ('would', 'MD'),
#  ('buy', 'VB'),
#  ('londonmanchester', 'JJR'),
#  ('ticket', 'NN'),
#  ('cheaper', 'JJR'),
#  ('yet', 'RB'),
#  ('covers', 'NNS'),
#  ('journey', 'VBP'),
#  ('read', 'VBN'),
#  ('anthony', 'NN'),
#  ('smith', 'NN'),
#  ('chief', 'JJ'),
#  ('executive', 'NN'),
#  ('independent', 'JJ'),
#  ('watchdog', 'JJ'),
#  ('transport', 'NN'),
#  ('focus', 'NN'),
#  ('said', 'VBD'),
#  ('example', 'NN'),
#  ('underlines', 'NNS'),
#  ('need', 'VBP'),
#  ('radical', 'JJ'),
#  ('overhaul', 'NN'),
#  ('fares', 'NNS'),
#  ('structure', 'NN'),
#  ('need', 'VBP'),
#  ('parttime', 'NN'),
#  ('season', 'NN'),
#  ('tickets', 'NNS'),
#  ('deals', 'NNS'),
#  ('fill', 'VBP'),
#  ('offpeak', 'JJ'),
#  ('seats', 'NNS'),
#  ('modern', 'VBP'),
#  ('ticketing', 'VBG'),
#  ('system', 'NN'),
#  ('suit', 'NN'),
#  ('way', 'NN'),
#  ('travel', 'NN'),
#  ('department', 'NN'),
#  ('transport', 'NN'),
#  ('spokesperson', 'NN'),
#  ('said', 'VBD'),
#  ('figures', 'NNS'),
#  ('take', 'VBP'),
#  ('account', 'VBP'),
#  ('full', 'JJ'),
#  ('range', 'NN'),
#  ('fares', 'NNS'),
#  ('available', 'JJ'),
#  ('cheapest', 'JJS'),
#  ('advance', 'NN'),
#  ('fares', 'NNS'),
#  ('europe', 'VBP'),
#  ('many', 'JJ'),
#  ('journeys', 'NNS'),
#  ('made', 'VBN'),
#  ('fraction', 'NN'),
#  ('price', 'NN'),
#  ('rail', 'NN'),
#  ('fares', 'NNS'),
#  ('across', 'IN'),
#  ('britain', 'NN'),
#  ('traditionally', 'RB'),
#  ('rise', 'VBP'),
#  ('first', 'JJ'),
#  ('working', 'VBG'),
#  ('day', 'NN'),
#  ('january', 'JJ'),
#  ('regulated', 'VBD'),
#  ('fares', 'NNS'),
#  ('increased', 'JJ'),
#  ('average', 'JJ'),
#  ('per', 'IN'),
#  ('cent', 'NN'),
#  ('fractionally', 'RB'),
#  ('retail', 'JJ'),
#  ('price', 'NN'),
#  ('index', 'NN'),
#  ...]

# %%
# preprocessing_3: 품사 태깅 
data_df.to_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_3.csv")

# %%
import pandas as pd

data_df = pd.read_csv('C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_3.csv', index_col = 0)
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  [('fear', 'NN'), ('automation', 'NN'), ('artif...
# 1     2019-01-02  [('manufacturing', 'NN'), ('sector', 'NN'), ('...
# 2     2019-01-03  [('futures', 'NNS'), ('put', 'VBD'), ('nasdaq'...
# 3     2019-01-04  [('khartoumcairo', 'NN'), ('reuters', 'NNS'), ...
# 4     2019-01-07  [('london', 'JJ'), ('reuters', 'NNS'), ('set',...
# ...          ...                                                ...
# 1246  2023-10-25  [('new', 'JJ'), ('home', 'NN'), ('sales', 'NNS...
# 1247  2023-10-26  [('stocks', 'NNS'), ('fell', 'VBD'), ('thursda...
# 1248  2023-10-27  [('benchmark', 'NN'), ('amp', 'NN'), ('index',...
# 1249  2023-10-30  [('petronas', 'NNS'), ('greenko', 'VBP'), ('fo...
# 1250  2023-10-31  [('young', 'JJ'), ('americans', 'NNS'), ('incl...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
data_df['Text'][0]
# Out:
# "[('fear', 'NN'), ('automation', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('spurred', 'VBD'), ('countless', 'JJ'), ('conversations', 'NNS'), ('future', 'JJ'), ('work', 'NN'), ('humans', 'NNS'), ('fare', 'JJ'), ('age', 'NN'), ('robots', 'VBD'), ('many', 'JJ'), ('fear', 'JJ'), ('technological', 'JJ'), ('unemployment', 'NN'), ('others', 'NNS'), ('preemptively', 'RB'), ('denounce', 'JJ'), ('future', 'JJ'), ('income', 'NN'), ('inequality', 'NN'), ('confront', 'VBP'), ('dismal', 'JJ'), ('future', 'JJ'), ('work', 'NN'), ('many', 'JJ'), ('policy', 'NN'), ('world', 'NN'), ('tech', 'NN'), ('world', 'NN'), ('even', 'RB'), ('aspiring', 'VBG'), ('presidential', 'JJ'), ('candidates', 'NNS'), ('like', 'IN'), ('andrew', 'NN'), ('yang', 'NN'), ('tout', 'IN'), ('promise', 'NN'), ('universal', 'JJ'), ('basic', 'JJ'), ('income', 'NN'), ('ubi', 'JJ'), ('overcome', 'JJ'), ('uncertainties', 'NNS'), ('whether', 'IN'), ('policymakers', 'NNS'), ('even', 'RB'), ('consider', 'VBP'), ('ideas', 'NNS'), ('ubi', 'RB'), ('given', 'VBN'), ('recent', 'JJ'), ('studies', 'NNS'), ('suggest', 'VBP'), ('expanded', 'VBN'), ('labor', 'NN'), ('market', 'NN'), ('future', 'NN'), ('relatively', 'RB'), ('strong', 'JJ'), ('current', 'JJ'), ('economic', 'JJ'), ('conditions', 'NNS'), ('still', 'RB'), ('open', 'JJ'), ('question', 'NN'), ('rather', 'RB'), ('focusing', 'VBG'), ('familiar', 'JJ'), ('concerns', 'NNS'), ('ubi', 'JJ'), ('risk', 'NN'), ('dependency', 'NN'), ('price', 'NN'), ('tag', 'NN'), ('implement', 'NN'), ('work', 'NN'), ('often', 'RB'), ('provides', 'VBZ'), ('meaning', 'VBG'), ('one', 'CD'), ('life', 'NN'), ('worthwhile', 'NN'), ('recognize', 'VB'), ('case', 'NN'), ('broad', 'JJ'), ('radical', 'JJ'), ('reform', 'NN'), ('economic', 'JJ'), ('system', 'NN'), ('actually', 'RB'), ('rather', 'RB'), ('weak', 'JJ'), ('although', 'IN'), ('influential', 'JJ'), ('forecast', 'NN'), ('oxford', 'NN'), ('university', 'NN'), ('reported', 'VBD'), ('percent', 'NN'), ('jobs', 'NNS'), ('percent', 'NN'), ('high', 'JJ'), ('risk', 'NN'), ('automated', 'VBD'), ('following', 'VBG'), ('years', 'NNS'), ('recent', 'JJ'), ('study', 'NN'), ('organisation', 'NN'), ('economic', 'JJ'), ('cooperation', 'NN'), ('development', 'NN'), ('oecd', 'NN'), ('puts', 'VBZ'), ('figure', 'JJ'), ('percent', 'NN'), ('united', 'JJ'), ('states', 'NNS'), ('percent', 'NN'), ('united', 'JJ'), ('kingdom', 'NN'), ('moreover', 'RB'), ('recent', 'JJ'), ('study', 'NN'), ('future', 'NN'), ('jobs', 'NNS'), ('world', 'NN'), ('economic', 'JJ'), ('forum', 'NN'), ('predicts', 'NNS'), ('robots', 'VBP'), ('displace', 'NN'), ('million', 'CD'), ('jobs', 'NNS'), ('globally', 'RB'), ('create', 'VBP'), ('million', 'CD'), ('new', 'JJ'), ('ones', 'NNS'), ('net', 'JJ'), ('positive', 'JJ'), ('overall', 'JJ'), ('numbers', 'NNS'), ('hardly', 'RB'), ('scary', 'JJ'), ('concerns', 'NNS'), ('remain', 'VBP'), ('growing', 'VBG'), ('number', 'NN'), ('researchers', 'NNS'), ('across', 'IN'), ('political', 'JJ'), ('spectrum', 'NN'), ('taking', 'VBG'), ('interest', 'NN'), ('concept', 'NN'), ('ubi', 'RB'), ('much', 'JJ'), ('automation', 'NN'), ('disruption', 'NN'), ('lies', 'VBZ'), ('heart', 'NN'), ('discussions', 'NNS'), ('future', 'JJ'), ('work', 'NN'), ('comes', 'VBZ'), ('silicon', 'JJ'), ('valley', 'NN'), ('entrepreneurs', 'NNS'), ('valley', 'VBP'), ('often', 'RB'), ('tried', 'VBN'), ('suggest', 'VBP'), ('proactive', 'JJ'), ('solutions', 'NNS'), ('one', 'CD'), ('latest', 'JJS'), ('experiments', 'NNS'), ('ubi', 'JJ'), ('one', 'CD'), ('currently', 'RB'), ('pursued', 'VBN'), ('combinator', 'NN'), ('silicon', 'NN'), ('valley', 'NN'), ('seed', 'NN'), ('funder', 'NN'), ('combinator', 'NN'), ('reported', 'VBD'), ('million', 'CD'), ('ubi', 'JJ'), ('experiment', 'JJ'), ('start', 'NN'), ('experiment', 'NN'), ('consists', 'VBZ'), ('giving', 'VBG'), ('people', 'NNS'), ('per', 'IN'), ('month', 'NN'), ('five', 'CD'), ('years', 'NNS'), ('discussing', 'VBG'), ('motivation', 'NN'), ('experiment', 'NN'), ('assert', 'JJ'), ('extreme', 'JJ'), ('poverty', ...

# %%
# 필요한 품사만 추출
desired_pos = ['NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD', 'VBT', 'VBN', 'VBP', 'VBZ', 'RB', 'RBP', 'RBS', 'JJ', 'JJR', 'JJS']

# 'Text' 열의 각 행에 대해 작업 수행
for idx, row in data_df.iterrows():
    # 'Text' 열의 값이 문자열인 경우에 대비하여 리스트로 변환
    word_pos_list = eval(row['Text']) if isinstance(row['Text'], str) else row['Text']
    
    # 각 튜플에서 특정 품사들만 추출하여 새로운 리스트 생성
    filtered_words = [word for word, pos in word_pos_list if pos in desired_pos]
    
    # 새로운 리스트를 'Text' 열에 저장
    data_df.at[idx, 'Text'] = filtered_words

# %%
data_df['Text'][0]
# Out:
# ['fear',
#  'automation',
#  'artificial',
#  'intelligence',
#  'spurred',
#  'countless',
#  'conversations',
#  'future',
#  'work',
#  'humans',
#  'fare',
#  'age',
#  'robots',
#  'many',
#  'fear',
#  'technological',
#  'unemployment',
#  'others',
#  'preemptively',
#  'denounce',
#  'future',
#  'income',
#  'inequality',
#  'confront',
#  'dismal',
#  'future',
#  'work',
#  'many',
#  'policy',
#  'world',
#  'tech',
#  'world',
#  'even',
#  'presidential',
#  'candidates',
#  'andrew',
#  'yang',
#  'promise',
#  'universal',
#  'basic',
#  'income',
#  'ubi',
#  'overcome',
#  'uncertainties',
#  'policymakers',
#  'even',
#  'consider',
#  'ideas',
#  'ubi',
#  'given',
#  'recent',
#  'studies',
#  'suggest',
#  'expanded',
#  'labor',
#  'market',
#  'future',
#  'relatively',
#  'strong',
#  'current',
#  'economic',
#  'conditions',
#  'still',
#  'open',
#  'question',
#  'rather',
#  'familiar',
#  'concerns',
#  'ubi',
#  'risk',
#  'dependency',
#  'price',
#  'tag',
#  'implement',
#  'work',
#  'often',
#  'provides',
#  'life',
#  'worthwhile',
#  'recognize',
#  'case',
#  'broad',
#  'radical',
#  'reform',
#  'economic',
#  'system',
#  'actually',
#  'rather',
#  'weak',
#  'influential',
#  'forecast',
#  'oxford',
#  'university',
#  'reported',
#  'percent',
#  'jobs',
#  'percent',
#  'high',
#  'risk',
#  'automated',
#  'years',
#  'recent',
#  'study',
#  'organisation',
#  'economic',
#  'cooperation',
#  'development',
#  'oecd',
#  'puts',
#  'figure',
#  'percent',
#  'united',
#  'states',
#  'percent',
#  'united',
#  'kingdom',
#  'moreover',
#  'recent',
#  'study',
#  'future',
#  'jobs',
#  'world',
#  'economic',
#  'forum',
#  'predicts',
#  'robots',
#  'displace',
#  'jobs',
#  'globally',
#  'create',
#  'new',
#  'ones',
#  'net',
#  'positive',
#  'overall',
#  'numbers',
#  'hardly',
#  'scary',
#  'concerns',
#  'remain',
#  'number',
#  'researchers',
#  'political',
#  'spectrum',
#  'interest',
#  'concept',
#  'ubi',
#  'much',
#  'automation',
#  'disruption',
#  'lies',
#  'heart',
#  'discussions',
#  'future',
#  'work',
#  'comes',
#  'silicon',
#  'valley',
#  'entrepreneurs',
#  'valley',
#  'often',
#  'tried',
#  'suggest',
#  'proactive',
#  'solutions',
#  'latest',
#  'experiments',
#  'ubi',
#  'currently',
#  'pursued',
#  'combinator',
#  'silicon',
#  'valley',
#  'seed',
#  'funder',
#  'combinator',
#  'reported',
#  'ubi',
#  'experiment',
#  'start',
#  'experiment',
#  'consists',
#  'people',
#  'month',
#  'years',
#  'motivation',
#  'experiment',
#  'assert',
#  'extreme',
#  'poverty',
#  'dramatically',
#  'increased',
#  'middle',
#  'class',
#  'employment',
#  'incomes',
#  'become',
#  'volatile',
#  'unpredictable',
#  'fortunately',
#  'none',
#  'data',
#  'confirm',
#  'dreary',
#  'assertions',
#  'recent',
#  'report',
#  'released',
#  'census',
#  'bureau',
#  'poverty',
#  'continued',
#  'decline',
#  'third',
#  'consecutive',
#  'year',
#  'modest',
#  'positive',
#  'wage',
#  'growth',
#  'inequality',
#  'statistically',
#  'different',
#  'middle',
#  'class',
#  'economist',
#  'mark',
#  'perry',
#  'reports',
#  'people',
#  'better',
#  'members',
#  'middle',
#  'class',
#  'ranks',
#  'upper',
#  'class',
#  'middle',
#  'shrink',
#  'latest',
#  'unemployment',
#  'rate',
#  'percent',
#  'current',
#  'job',
#  'openings',
#  'bureau',
#  'labor',
#  'statistics',
#  'need',
#  'experiment',
#  'dramatic',
#  'changes',
#  'social',
#  'safety',
#  'net',
#  'ubi',
#  'seems',
#  'overblown',
#  'furthermore',
#  'recent',
#  'bloomberg',
#  'article',
#  'based',
#  'study',
#  'conference',
#  'board',
#  'even',
#  'describes',
#  'shortage',
#  'workers',
#  'many',
#  'industries',
#  'typically',
#  'vocal',
#  'supporters',
#  'ubi',
#  'everyone',
#  'silicon',
#  'valley',
#  'fearful',
#  'future',
#  'work',
#  'actually',
#  'welcome',
#  'column',
#  'wired',
#  'magazine',
#  'palantir',
#  'founder',
#  'joe',
#  'lonsdale',
#  'outlined',
#  'various',
#  'industries',
#  'new',
#  'types',
#  'jobs',
#  'continue',
#  'created',
#  'lonsdale',
#  'puts',
#  'money',
#  'mouth',
#  'work',
#  'palantir',
#  'harnesses',
#  'power',
#  'solve',
#  'complex',
#  'problems',
#  'big',
#  'data',
#  'variety',
#  'industries',
#  'productivity',
#  'nature',
#  'jobs',
#  'rather',
#  'much',
#  'discussion',
#  'ubi',
#  'future',
#  'work',
#  'triggered',
#  'concern',
#  'future',
#  'lack',
#  'upward',
#  'economic',
#  'mobility',
#  'increase',
#  'income',
#  'inequality',
#  'however',
#  'reasons',
#  'less',
#  'upward',
#  'economic',
#  'mobility',
#  'united',
#  'states',
#  'wed',
#  'discussed',
#  'researchers',
#  'raj',
#  'chetty',
#  'scott',
#  'winship',
#  'almost',
#  'certainly',
#  'due',
#  'factors',
#  'require',
#  'drastic',
#  'change',
#  'welfare',
#  'economic',
#  'policies',
#  'factor',
#  'decline',
#  'male',
#  'labor',
#  'force',
#  'participation',
#  'complex',
#  'problem',
#  'multiple',
#  'causes',
#  'likely',
#  'excessive',
#  'use',
#  'disability',
#  'programs',
#  'job',
#  'polarization',
#  'workers',
#  'demand',
#  'skills',
#  'gap',
#  'soft',
#  'skills',
#  'included',
#  'highlighted',
#  'people',
#  'mike',
#  'rowe',
#  'creates',
#  'frictions',
#  'labor',
#  'market',
#  'reasons',
#  'include',
#  'steep',
#  'decline',
#  'business',
#  'dynamism',
#  'fewer',
#  'startups',
#  'created',
#  'due',
#  'variety',
#  'factors',
#  'occupational',
#  'licensing',
#  'laws',
#  'restrict',
#  'employment',
#  'opportunities',
#  'shown',
#  'related',
#  'lower',
#  'levels',
#  'economic',
#  'mobility',
#  'higher',
#  'levels',
#  'income',
#  'inequality',
#  'local',
#  'laws',
#  'affect',
#  'lowincome',
#  'workers',
#  'afford',
#  'live',
#  'high',
#  'incarceration',
#  'rates',
#  'affect',
#  'opportunities',
#  'upward',
#  'economic',
#  'mobility',
#  'leave',
#  'many',
#  'people',
#  'especially',
#  'males',
#  'labor',
#  'force',
#  'issues',
#  'often',
#  'state',
#  'local',
#  'level',
#  'help',
#  'produce',
#  'dynamic',
#  'healthy',
#  'economy',
#  'barriers',
#  'currently',
#  'prevent',
#  'people',
#  'income',
#  'ladder',
#  'seem',
#  'mundane',
#  'comparison',
#  'radical',
#  'proposals',
#  'problems',
#  'increase',
#  'ability',
#  'face',
#  'future',
#  'automation',
#  'likely',
#  'boost',
#  'upward',
#  'mobility',
#  'even',
#  'reduce',
#  'inequality',
#  'way',
#  'innovation',
#  'human',
#  'ingenuity',
#  'ultimate',
#  'resource',
#  'cornerstones',
#  'discussion',
#  'future',
#  'work',
#  'gonzalo',
#  'schwarz',
#  'president',
#  'ceo',
#  'institute',
#  'based',
#  'nonprofit',
#  'organization',
#  'behalf',
#  'free',
#  'markets',
#  'limited',
#  'government',
#  'regulations',
#  'sankaran',
#  'narencalendar',
#  'likely',
#  'interesting',
#  'year',
#  'investors',
#  'market',
#  'braces',
#  'nearterm',
#  'volatility',
#  'major',
#  'nearterm',
#  'event',
#  'general',
#  'elections',
#  'date',
#  'indian',
#  'equity',
#  'market',
#  'fairly',
#  'valued',
#  'cheap',
#  'expensive',
#  'importantly',
#  'focus',
#  'individual',
#  'stock',
#  'plenty',
#  'opportunities',
#  'available',
#  'attractive',
#  'valuations',
#  'several',
#  'uplifting',
#  'factors',
#  'market',
#  'upbeat',
#  'begin',
#  'fall',
#  'crude',
#  'oil',
#  'prices',
#  'sentiment',
#  'booster',
#  'greatly',
#  'reduced',
#  'pressure',
#  'twin',
#  'deficits',
#  'current',
#  'account',
#  'fiscal',
#  'consequently',
#  'rupee',
#  'turned',
#  'dollar',
#  'bond',
#  'yields',
#  'interest',
#  'burden',
#  'economy',
#  'macro',
#  'figures',
#  'signs',
#  'financial',
#  'stability',
#  'mediumterm',
#  'perspective',
#  'equity',
#  'market',
#  'likely',
#  'remain',
#  'volatile',
#  'historically',
#  'election',
#  'years',
#  'proved',
#  'volatile',
#  'financial',
#  'markets',
#  'general',
#  'election',
#  'years',
#  'stock',
#  'market',
#  'provided',
#  'investors',
#  'intermittent',
#  'opportunities',
#  'invest',
#  'times',
#  'best',
#  'investment',
#  'strategy',
#  'use',
#  'systematic',
#  'investment',
#  'route',
#  'accumulate',
#  'equities',
#  'believe',
#  'year',
#  'systematically',
#  'accumulate',
#  'equities',
#  'sip',
#  'stps',
#  'emotional',
#  'biases',
#  'bay',
#  'accumulation',
#  'phase',
#  'generally',
#  'comes',
#  'precursor',
#  'bull',
#  'run',
#  'thus',
#  'important',
#  'patient',
#  'remain',
#  'invested',
#  'phase',
#  'make',
#  'outsized',
#  'gains',
#  'likely',
#  'market',
#  'uptick',
#  'ensues',
#  'phase',
#  'recent',
#  'example',
#  'phase',
#  'period',
#  'stock',
#  'markets',
#  'largely',
#  'rangebound',
#  'investors',
#  'stayed',
#  'invested',
#  'rewards',
#  'came',
#  'years',
#  'stock',
#  'market',
#  'entered',
#  'bull',
#  'phase',
#  'amidst',
#  'investors',
#  'need',
#  'watchful',
#  'factors',
#  'begin',
#  'fed',
#  'stance',
#  'interest',
#  'rates',
#  'factor',
#  'watch',
#  'meaningful',
#  'rally',
#  'indian',
#  'equities',
#  'likely',
#  'fed',
#  'done',
#  'tightening',
#  'accumulation',
#  'phase',
#  'likely',
#  'come',
#  'end',
#  'view',
#  'stance',
#  'believe',
#  'current',
#  'climate',
#  'conducive',
#  'investors',
#  'initiate',
#  'continue',
#  'systematic',
#  'investment',
#  'equity',
#  'assets',
#  'smallcaps',
#  'midcaps',
#  'value',
#  'funds',
#  'lumpsum',
#  'investments',
#  'balanced',
#  'advantage',
#  'funds',
#  'equity',
#  'savings',
#  'funds',
#  'preferred',
#  'vehicles',
#  'fund',
#  'categories',
#  'exposure',
#  'equity',
#  'debt',
#  'thus',
#  'provide',
#  'margin',
#  'safety',
#  'things',
#  'get',
#  'choppy',
#  'terms',
#  'themes',
#  'positive',
#  'special',
#  'situations',
#  'volatility',
#  'debt',
#  'dynamic',
#  'duration',
#  'schemes',
#  'benefit',
#  'volatility',
#  'low',
#  'duration',
#  'funds',
#  'tend',
#  'mitigate',
#  'interest',
#  'rate',
#  'volatility',
#  'instruments',
#  'maturity',
#  'range',
#  'years',
#  'accrual',
#  'schemes',
#  'capture',
#  'current',
#  'elevated',
#  'yields',
#  'categories',
#  'positive',
#  'look',
#  'hold',
#  'naren',
#  'cio',
#  'icici',
#  'prudential',
#  'mutual',
#  'fund',
#  'views',
#  'latest',
#  'rail',
#  'fare',
#  'rise',
#  'takes',
#  'effect',
#  'first',
#  'day',
#  'pushed',
#  'cost',
#  'intercity',
#  'travel',
#  'commuters',
#  'mile',
#  'anytime',
#  'standardclass',
#  'fare',
#  'mile',
#  'journey',
#  'swindon',
#  'didcot',
#  'parkway',
#  'rises',
#  'january',
#  'price',
#  'mile',
#  'gwr',
#  'fare',
#  'option',
#  'commuters',
#  'want',
#  'walk',
#  'ticket',
#  'minute',
#  'journey',
#  'join',
#  'independent',
#  'minds',
#  'exclusive',
#  'articles',
#  'events',
#  'advertisingfree',
#  'read',
#  'month',
#  'start',
#  'free',
#  'trial',
#  'get',
#  'best',
#  'independent',
#  'independent',
#  'minds',
#  'subscription',
#  'month',
#  'start',
#  'free',
#  'trial',
#  'heathrow',
#  'express',
#  'remains',
#  'britains',
#  'priciest',
#  'train',
#  'mile',
#  'significant',
#  'intercity',
#  'journey',
#  'rise',
#  'pound',
#  'mile',
#  'unprecedented',
#  'mile',
#  'trip',
#  'watford',
#  'junction',
#  'stockport',
#  'virgin',
#  'trains',
#  'also',
#  'exceeds',
#  'mile',
#  'fare',
#  'rises',
#  'rate',
#  'rational',
#  'traveller',
#  'buy',
#  'londonmanchester',
#  'ticket',
#  'cheaper',
#  'yet',
#  'covers',
#  'journey',
#  'read',
#  'anthony',
#  'smith',
#  'chief',
#  'executive',
#  'independent',
#  'watchdog',
#  'transport',
#  'focus',
#  'said',
#  'example',
#  'underlines',
#  'need',
#  'radical',
#  'overhaul',
#  'fares',
#  'structure',
#  'need',
#  'parttime',
#  'season',
#  'tickets',
#  'deals',
#  'fill',
#  'offpeak',
#  'seats',
#  'modern',
#  'system',
#  'suit',
#  'way',
#  'travel',
#  'department',
#  'transport',
#  'spokesperson',
#  'said',
#  'figures',
#  'take',
#  'account',
#  'full',
#  'range',
#  'fares',
#  'available',
#  'cheapest',
#  'advance',
#  'fares',
#  'europe',
#  'many',
#  'journeys',
#  'made',
#  'fraction',
#  'price',
#  'rail',
#  'fares',
#  'britain',
#  'traditionally',
#  'rise',
#  'first',
#  'day',
#  'january',
#  'regulated',
#  'fares',
#  'increased',
#  'average',
#  'cent',
#  'fractionally',
#  'retail',
#  'price',
#  'index',
#  'rpi',
#  'july',
#  'category',
#  'includes',
#  'season',
#  'tickets',
#  'london',
#  'area',
#  'anytime',
#  'fares',
#  'major',
#  'cities',
#  'many',
#  'offpeak',
#  'returns',
#  'longdistance',
#  'journeys',
#  'walk',
#  'prices',
#  'typically',
#  'rise',
#  'percentage',
#  'postchristmas',
#  'trains',
#  'marred',
#  'engineering',
#  'works',
#  'strikes',
#  'mick',
#  'whelan',
#  'general',
#  'secretary',
#  'train',
#  'drivers',
#  'union',
#  'aslef',
#  'said',
#  'wages',
#  'arent',
#  'pace',
#  'inflation',
#  'yet',
#  'train',
#  'companies',
#  'chum',
#  'transport',
#  'secretary',
#  'chris',
#  'prices',
#  'yet',
#  'robert',
#  'nisbet',
#  'regional',
#  'director',
#  'rail',
#  'delivery',
#  'group',
#  'represent',
#  'rail',
#  'industry',
#  'told',
#  'independent',
#  'nobody',
#  'wants',
#  'pay',
#  'travel',
#  'money',
#  'fares',
#  'crucial',
#  'investment',
#  'railway',
#  'passengers',
#  'want',
#  'economy',
#  'needs',
#  'improved',
#  'carriages',
#  'better',
#  'connections',
#  'reliable',
#  'journeys',
#  'read',
#  'fares',
#  'rise',
#  'comes',
#  'terrible',
#  ...]

# %%
# preprocessing_4: 명사, 동사, 형용사, 부사만 남긴 것 
data_df.to_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_4.csv")

# %% [markdown]
# ###### 표제어 추출

# %%
import pandas as pd

data_df = pd.read_csv('C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_4.csv', index_col = 0)
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  ['fear', 'automation', 'artificial', 'intellig...
# 1     2019-01-02  ['manufacturing', 'sector', 'hit', 'ninemonth'...
# 2     2019-01-03  ['futures', 'put', 'composite', 'heavily', 'we...
# 3     2019-01-04  ['khartoumcairo', 'reuters', 'short', 'time', ...
# 4     2019-01-07  ['london', 'reuters', 'set', 'strong', 'employ...
# ...          ...                                                ...
# 1246  2023-10-25  ['new', 'home', 'sales', 'united', 'states', '...
# 1247  2023-10-26  ['stocks', 'fell', 'thursday', 'pressure', 'di...
# 1248  2023-10-27  ['benchmark', 'amp', 'index', 'closed', 'corre...
# 1249  2023-10-30  ['petronas', 'greenko', 'founders', 'gic', 'se...
# 1250  2023-10-31  ['young', 'americans', 'gen', 'sights', 'set',...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
from nltk.stem import WordNetLemmatizer

# NLTK WordNetLemmatizer를 사용하여 표제어 추출
lemmatizer = WordNetLemmatizer()

# 'Text' 열의 각 행에 대해 작업 수행
for idx, row in data_df.iterrows():
    # 'Text' 열의 값이 문자열인 경우에 대비하여 리스트로 변환
    word_list = eval(row['Text']) if isinstance(row['Text'], str) else row['Text']
    
    # 표제어 추출
    lemmatized_words = [lemmatizer.lemmatize(word) for word in word_list]
    
    # 새로운 리스트를 'Text' 열에 저장
    data_df.at[idx, 'Text'] = lemmatized_words

# %%
# preprocessing_5: 정규 표현식, 불용어 처리, 품사 태깅 및 제거, 표제어 추출 완료 -> 전처리 완료
data_df.to_csv("C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_5.csv")

# %% [markdown]
# ##### 라벨_상승, 하락

# %%
import pandas as pd

data_df = pd.read_csv('C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/preprocessing_5.csv', index_col = 0)
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  ['fear', 'automation', 'artificial', 'intellig...
# 1     2019-01-02  ['manufacturing', 'sector', 'hit', 'ninemonth'...
# 2     2019-01-03  ['future', 'put', 'composite', 'heavily', 'wei...
# 3     2019-01-04  ['khartoumcairo', 'reuters', 'short', 'time', ...
# 4     2019-01-07  ['london', 'reuters', 'set', 'strong', 'employ...
# ...          ...                                                ...
# 1246  2023-10-25  ['new', 'home', 'sale', 'united', 'state', 'su...
# 1247  2023-10-26  ['stock', 'fell', 'thursday', 'pressure', 'dis...
# 1248  2023-10-27  ['benchmark', 'amp', 'index', 'closed', 'corre...
# 1249  2023-10-30  ['petronas', 'greenko', 'founder', 'gic', 'set...
# 1250  2023-10-31  ['young', 'american', 'gen', 'sight', 'set', '...
#
#       closing price fluctuation
# 0             2.435       0.00%
# 1             2.394      -1.69%
# 2             2.351      -1.80%
# 3             2.412       2.59%
# 4             2.410      -0.08%
# ...             ...         ...
# 1246          5.399      -0.06%
# 1247          5.395      -0.07%
# 1248          5.408       0.24%
# 1249          5.400      -0.15%
# 1250          5.394      -0.11%
#
# [1251 rows x 4 columns]

# %%
# pct_change() 함수
# 현재 값과 이전 요소 값의 백분율 변화량을 연산하는 함수 -> 변화율
data_df['daily_roc'] = data_df['closing price'].pct_change()

# # 변화량 
# data_df['Daily_rtn'] = data_df['Daily_rtn'].diff()
data_df
# Out:
#             date                                               Text  \
# 0     2019-01-01  ['fear', 'automation', 'artificial', 'intellig...
# 1     2019-01-02  ['manufacturing', 'sector', 'hit', 'ninemonth'...
# 2     2019-01-03  ['future', 'put', 'composite', 'heavily', 'wei...
# 3     2019-01-04  ['khartoumcairo', 'reuters', 'short', 'time', ...
# 4     2019-01-07  ['london', 'reuters', 'set', 'strong', 'employ...
# ...          ...                                                ...
# 1246  2023-10-25  ['new', 'home', 'sale', 'united', 'state', 'su...
# 1247  2023-10-26  ['stock', 'fell', 'thursday', 'pressure', 'dis...
# 1248  2023-10-27  ['benchmark', 'amp', 'index', 'closed', 'corre...
# 1249  2023-10-30  ['petronas', 'greenko', 'founder', 'gic', 'set...
# 1250  2023-10-31  ['young', 'american', 'gen', 'sight', 'set', '...
#
#       closing price fluctuation  daily_roc
# 0             2.435       0.00%        NaN
# 1             2.394      -1.69%  -0.016838
# 2             2.351      -1.80%  -0.017962
# 3             2.412       2.59%   0.025946
# 4             2.410      -0.08%  -0.000829
# ...             ...         ...        ...
# 1246          5.399      -0.06%  -0.000555
# 1247          5.395      -0.07%  -0.000741
# 1248          5.408       0.24%   0.002410
# 1249          5.400      -0.15%  -0.001479
# 1250          5.394      -0.11%  -0.001111
#
# [1251 rows x 5 columns]

# %%
data_df['rate_roc'] = data_df['daily_roc'].apply(lambda x: '상승' if x > 0 else ('하락' if x < 0 else '동결'))
data_df.to_csv('C:/Users/91pp9/Desktop/종로 새싹_핀테크 데이터 분석가 과정_1기/teamproject/Unclock-Watchers git/Minji/data/labeling_Text.csv')

# %%
data_df['Text'][0]
# Out:
# "['fear', 'automation', 'artificial', 'intelligence', 'spurred', 'countless', 'conversation', 'future', 'work', 'human', 'fare', 'age', 'robot', 'many', 'fear', 'technological', 'unemployment', 'others', 'preemptively', 'denounce', 'future', 'income', 'inequality', 'confront', 'dismal', 'future', 'work', 'many', 'policy', 'world', 'tech', 'world', 'even', 'presidential', 'candidate', 'andrew', 'yang', 'promise', 'universal', 'basic', 'income', 'ubi', 'overcome', 'uncertainty', 'policymakers', 'even', 'consider', 'idea', 'ubi', 'given', 'recent', 'study', 'suggest', 'expanded', 'labor', 'market', 'future', 'relatively', 'strong', 'current', 'economic', 'condition', 'still', 'open', 'question', 'rather', 'familiar', 'concern', 'ubi', 'risk', 'dependency', 'price', 'tag', 'implement', 'work', 'often', 'provides', 'life', 'worthwhile', 'recognize', 'case', 'broad', 'radical', 'reform', 'economic', 'system', 'actually', 'rather', 'weak', 'influential', 'forecast', 'oxford', 'university', 'reported', 'percent', 'job', 'percent', 'high', 'risk', 'automated', 'year', 'recent', 'study', 'organisation', 'economic', 'cooperation', 'development', 'oecd', 'put', 'figure', 'percent', 'united', 'state', 'percent', 'united', 'kingdom', 'moreover', 'recent', 'study', 'future', 'job', 'world', 'economic', 'forum', 'predicts', 'robot', 'displace', 'job', 'globally', 'create', 'new', 'one', 'net', 'positive', 'overall', 'number', 'hardly', 'scary', 'concern', 'remain', 'number', 'researcher', 'political', 'spectrum', 'interest', 'concept', 'ubi', 'much', 'automation', 'disruption', 'lie', 'heart', 'discussion', 'future', 'work', 'come', 'silicon', 'valley', 'entrepreneur', 'valley', 'often', 'tried', 'suggest', 'proactive', 'solution', 'latest', 'experiment', 'ubi', 'currently', 'pursued', 'combinator', 'silicon', 'valley', 'seed', 'funder', 'combinator', 'reported', 'ubi', 'experiment', 'start', 'experiment', 'consists', 'people', 'month', 'year', 'motivation', 'experiment', 'assert', 'extreme', 'poverty', 'dramatically', 'increased', 'middle', 'class', 'employment', 'income', 'become', 'volatile', 'unpredictable', 'fortunately', 'none', 'data', 'confirm', 'dreary', 'assertion', 'recent', 'report', 'released', 'census', 'bureau', 'poverty', 'continued', 'decline', 'third', 'consecutive', 'year', 'modest', 'positive', 'wage', 'growth', 'inequality', 'statistically', 'different', 'middle', 'class', 'economist', 'mark', 'perry', 'report', 'people', 'better', 'member', 'middle', 'class', 'rank', 'upper', 'class', 'middle', 'shrink', 'latest', 'unemployment', 'rate', 'percent', 'current', 'job', 'opening', 'bureau', 'labor', 'statistic', 'need', 'experiment', 'dramatic', 'change', 'social', 'safety', 'net', 'ubi', 'seems', 'overblown', 'furthermore', 'recent', 'bloomberg', 'article', 'based', 'study', 'conference', 'board', 'even', 'describes', 'shortage', 'worker', 'many', 'industry', 'typically', 'vocal', 'supporter', 'ubi', 'everyone', 'silicon', 'valley', 'fearful', 'future', 'work', 'actually', 'welcome', 'column', 'wired', 'magazine', 'palantir', 'founder', 'joe', 'lonsdale', 'outlined', 'various', 'industry', 'new', 'type', 'job', 'continue', 'created', 'lonsdale', 'put', 'money', 'mouth', 'work', 'palantir', 'harness', 'power', 'solve', 'complex', 'problem', 'big', 'data', 'variety', 'industry', 'productivity', 'nature', 'job', 'rather', 'much', 'discussion', 'ubi', 'future', 'work', 'triggered', 'concern', 'future', 'lack', 'upward', 'economic', 'mobility', 'increase', 'income', 'inequality', 'however', 'reason', 'le', 'upward', 'economic', 'mobility', 'united', 'state', 'wed', 'discussed', 'researcher', 'raj', 'chetty', 'scott', 'winship', 'almost', 'certainly', 'due', 'factor', 'require', 'drastic', 'change', 'welfare', 'economic', 'policy', 'factor', 'decline', 'male', 'labor', 'force', 'participation', 'complex', 'problem', 'multiple', 'cause', 'likely', 'excessive', 'use', 'disability', 'program', 'job', 'polarization', 'worker', 'deman ...

# %% [markdown]
# ##### n-gram
